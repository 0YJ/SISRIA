# %%
import  numpy  as  np
import matplotlib.pyplot  as plt
from os import listdir,walk
from os.path import isfile, join
from scipy.misc import imread
import math
import PIL
from keras.layers import Reshape,Dense
import numpy as np
from keras.layers import UpSampling2D,MaxPool2D,Conv2D,Activation,Dropout,BatchNormalization,Conv2DTranspose
from keras.models import Sequential,load_model
import matplotlib.pyplot as plt
from scipy.misc import imresize
from scipy import ndimage as nd

from skimage.measure import compare_psnr, compare_ssim
from tqdm import tqdm_notebook as tqdm
from keras.preprocessing.image import ImageDataGenerator
from skimage.color import ycbcr2rgb, rgb2ycbcr
from scipy.misc import imread
from os import listdir
import cv2
# Out:
# Using TensorFlow backend.

# %%
mypath='./image-dataset/HR/'
value_of_image=[]
impath=[]
fileslist=[]
for files in sorted(listdir(mypath)):
    
    images = join(mypath,files)
    impath.append(images)

# %%
impath

# %%
list_im = impath[0:8]
imgs    = [ PIL.Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]

imgs_comb1= np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs[0:4] ) )
imgs_comb2= np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs[4:8] ) )
imgs_comb = np.vstack([imgs_comb1,imgs_comb2])

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
#img
#imgs_comb.save( 'img.png' )

# %%
min_shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f5424fd8d257> in <module>()
# ----> 1 min_shape
#       2 x=np.reshape(100,(380,420,3),1)
#
# NameError: name 'min_shape' is not defined

# %%
#To combine all the images into one array:

x = np.array([np.array(Image.open(fname)) for fname in filelist])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7557e7e79038> in <module>()
#       2 #To combine all the images into one array:
#       3
# ----> 4 x = np.array([np.array(Image.open(fname)) for fname in filelist])
#
# <ipython-input-25-7557e7e79038> in <listcomp>(.0)
#       2 #To combine all the images into one array:
#       3
# ----> 4 x = np.array([np.array(Image.open(fname)) for fname in filelist])
#
# NameError: name 'Image' is not defined

# %%
import glob 
import cv2
filelist = glob.glob('./image-dataset/HR/*.png')

# %%
import imageio

mypath='./image-dataset/HR/'
value_of_image=[]
impath=[]
fileslist=[]
for files in sorted(listdir(mypath)):
    
    images = join(mypath,files)
    impath.append(images)
    
list_im = impath
imgs    = [ PIL.Image.open(i) for i in list_im ]

#  plt.figure(figsize=(30,20))
#plt.subplot(211)
#plt.imshow((imgs[5]))
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
print(min_shape)
min_shape = 480,320
imgs_comb1= list(np.asarray( i.resize(min_shape) ) for i in imgs)
np.shape(imgs_comb1)
plt.figure(figsize=(30,20))
plt.subplot(211)
plt.imshow((imgs_comb1[6]))
np.save('HR1.npy',imgs_comb1)
#np.savez_compressed('HRP.npz',imgs_comb1)
z=np.load('HR1.npy')
z.shape
# Out:
# (320, 480)
# (100, 320, 480, 3)

# %%
pics = np.array([imageio.imread(fname) for fname in glob.glob('./image-dataset/HR/*.png')])
pics = [np.expand_dims(pic, axis=0) for pic in pics]
np.shape(np.concatenate(pics))

x = np.asarray([np.array(PIL.Image.open(fname)) for fname in filelist])
#images = np.array([imageio.imread(fname) for fname in glob.glob('./image-dataset/HR/*.png')])
#print(images[5].shape)

print(pics[0].shape)
#x.dump('file.npy')
np.save('file.npy',x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a3656d0384b5> in <module>()
#       2 pics = np.array([imageio.imread(fname) for fname in glob.glob('./image-dataset/HR/*.png')])
#       3 pics = [np.expand_dims(pic, axis=0) for pic in pics]
# ----> 4 np.shape(np.concatenate(pics))
#       5
#       6 x = np.asarray([np.array(PIL.Image.open(fname)) for fname in filelist])
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
x = np.load('file.npy')

# %%
x.shape[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-449ff7bc6075> in <module>()
# ----> 1 x.shape[1]
#
# IndexError: tuple index out of range

# %%
x[5].shape[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-5bdc0b52c6c1> in <module>()
#       1 x[5].shape[0]
# ----> 2 y=np.resize(x,(x.shape[0],x.shape[1],x.shape[2],1))
#
# IndexError: tuple index out of range

# %%
plt.figure(figsize=(30,20))

plt.subplot(211)
plt.imshow((x[6]))
plt.show()

# %%
x=np.load('file.npy')
